# %% [markdown]
# ## Data load check

# %%
# Dependencies
from scivision import load_dataset
import matplotlib.pyplot as plt

# %%
#data_url = target_datasource['url'].item()
data_config = load_dataset("https://github.com/arvdv/ATI_data_repo")
data_config
# Out:
# data:
#   args:
#     path: https://raw.githubusercontent.com/arvdv/ATI_data_repo/main/.scivision/data.yml
#   description: ''
#   driver: intake.catalog.local.YAMLFileCatalog
#   metadata: {}

# %%
test = data_config.honey_bees().to_dask()
test_image = test[5,:,:,:]
test_image
# Out:
# <xarray.DataArray 'imread-0cc8af0de2621a181747fddbd6a98020' (y: 1000, x: 1000,
#                                                              channel: 3)>
# dask.array<getitem, shape=(1000, 1000, 3), dtype=uint8, chunksize=(1000, 1000, 3), chunktype=numpy.ndarray>
# Coordinates:
#     concat_dim  int32 5
#   * y           (y) int32 0 1 2 3 4 5 6 7 8 ... 992 993 994 995 996 997 998 999
#   * x           (x) int32 0 1 2 3 4 5 6 7 8 ... 992 993 994 995 996 997 998 999
#   * channel     (channel) int32 0 1 2

# %%
plt.imshow(test_image)
